# %% [markdown]
# **Nama : Isyamaetreya Savitri**
#
# **NIM : 121450037**
#
# **Kelas : RB**

# %% [markdown]
# # 1

# %% [markdown]
# ![Screenshot (630).png](data:image/png;base64,...)

# %% [markdown]
# # 2

# %% [markdown]
# ![Screenshot (631).png](data:image/png;base64,...)

# %% [markdown]
# # 3

# %% [markdown]
# ![Screenshot (632).png](data:image/png;base64,...)

# %% [markdown]
# # 4

# %% [markdown]
# Apa yang dimaksud dengan pure functional programming language?
#
# **Jawab :**
#
# Pure Functional Programming Language merupakan program yang hanya fokus pada fungsi matematika murni dan datanya tidak berubah setelah dibuat. Pada Pure Functional Programming Language menggunakan fungsi fungsi matematis sebagai dasar dalam memecahkan masalah dan proses pembuatan program.

# %% [markdown]
# # 5

# %% [markdown]
# Dari bahasa pemrograman FP di slide sebelumnya ( slide 14 ) , manakah
# yang termasuk pure functional programming language?
#
# **Jawab :**
#
# Pada slide 14 yang termasuk pure functional programming language adalah Lisp, Haskell, Scala, dan Standard ML .

# %% [markdown]
# # 6

# %%
def end(pw):
  if len(pw) > 100 or len(pw) == 0:
    print("Masukkan dan pilih angka dari 1 sampai 100")
  else:
    ascii = [str(ord(i)) for i in pw]
    enkripsi = ''.join(chr((int(j)//26)+80)+chr((int(j)%26)+80)+('+' if (int(j)//26)+80 > (int(j)%26)+80 else '-') for j in ascii)
    print("Enkripsi password anda adalah: ", enkripsi)

def newend(pw):
  split_ps = [(pw[k:k+3]) for k in range(0, len(pw), 3)]
  dekripsi = ''.join(chr(((ord(list(z)[0])-80)*26)+(ord(list(z)[1])-80)) for z in split_ps)
  print("Password anda adalah: ", dekripsi)

pw = input("Masukkan Password: ")
end (pw)

new = input("Masukkan endkripsi password ")
newend(new)
# Out:
# Masukkan Password: 787878
# Enkripsi password anda adalah:  RS-RT-RS-RT-RS-RT-
# Masukkan endkripsi password RS-RT-RS-RT-RS-RT-
# Password anda adalah:  787878
